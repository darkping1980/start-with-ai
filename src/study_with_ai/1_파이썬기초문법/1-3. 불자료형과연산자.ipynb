# %%
# 연습 : 
score = 75
passed = (score >= 60)
print(passed)
# Out:
# True

# %%
### 논리연산자
age = 28
print(not(age == 28))
# Out:
# False

# %% [markdown]
# 멤버십 연산자

# %%
text = "오늘 날씨가 비가 많이 오네요. 월요일입니다."

# in / not in
print("오늘" in text)
# Out:
# True

# %%
print("test")
# Out:
# test
