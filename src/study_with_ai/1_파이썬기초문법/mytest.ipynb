# %%
name = "홍길동"

age = 20

print(name)

print(age)
# Out:
# 홍길동
# 20

# %%
star = "*"
print(star * 10)
# Out:
# **********

# %%
text = "Python"
print(text[0])
print(text[-1])
# Out:
# P
# n

# %%
text = "Python"
print(text[0:2])
# Out:
# Py

# %%
text = "Python"
print(text[3:])
# Out:
# hon

# %%
text = "Python"
print(text[2:5])
# Out:
# tho
