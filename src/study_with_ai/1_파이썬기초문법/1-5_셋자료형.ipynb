# %% [markdown]
# ### 셋자료형
# - 중복 제거용으로 주로 쓰입니다.
# - {} 만듭니다: 딕셔너리와 구분해주세요

# %%
# 합집합 - 중복 제거한 전체 값 -> 기호는 | 를 사용하거나 union 메소드 를 사용
data1 = {1,2,3}  
data2 = {3,4,5}

data1 | data2
# Out:
# {1, 2, 3, 4, 5}

# %%
data3 = [1,2,2,2,3,3,5]
data4 = set(data3)
data4
# Out:
# {1, 2, 3, 5}

# %%
data1
# Out:
# {1, 2, 3}

# %%
data2
# Out:
# {3, 4, 5}

# %%
data1  | data2
# Out:
# {1, 2, 3, 4, 5}

# %%
data1.union(data2)
# Out:
# {1, 2, 3, 4, 5}

# %%
data1 & data2
# Out:
# {3}

# %%
data1.intersection(data2)
# Out:
# {3}

# %%
data1 - data2
# Out:
# {1, 2}

# %%
data2 - data1
# Out:
# {4, 5}

# %%
data1.difference(data2)
# Out:
# {1, 2}

# %%
data2.difference(data1)
# Out:
# {4, 5}
