# %% [markdown]
# ### 1. 변수와자료형

# %% [markdown]
# 값에 이름표를 붙이는 것을 변수라고 한다.
#
# - 숫자형 : 계산할 수 있는  값
#     - 정수(Int)
#     - 실수(Float)
#     - 8진수
#     - 16진수
# - 문자형 : 글자로 된 값

# %%
name = "김병주"
age = "46"
print(name)
# Out:
# 김병주

# %%
print(name)
# Out:
# 김병주

# %%
print(age)
# Out:
# 46

# %%
favorite_food  = "김치찌개"
print(favorite_food)
# Out:
# 김치찌개

# %%
favorite_food = "순두부"
print(favorite_food)
# Out:
# 순두부

# %%
number1 = "123"
number2 = 123

# %%
type(number1)
# Out:
# str

# %%
print(type(number1))
# Out:
# <class 'str'>

# %%
int(number1)
# Out:
# 123

# %%
float(number1)
# Out:
# 123.0

# %% [markdown]
# ### 2. 변수 네이밍 규칙
# - 영문, 숫자, 밑줄만 가능, 숫자로 시작 X
# - 예약어 X
# - 관례(PEP 8) : 변수는 소문자와 밑줄로 사용 -
#     - snake_case : 예) user_name
#     - CamelCase : 첫글자를 대문자로 : 예) UserInfo

# %% [markdown]
# ### 3. 숫자형
#
#     정수
#     실수
#     N진수

# %%
count = 42
pi = 3.14
octal = 0o17
hexa = 0xFF
big = 10_000_000

# %%
count * pi
# Out:
# 131.88

# %%
# 연습 : 반지름 5인 원의 넓이를 구해서 출력해 보세요 -> 반지름 변수, pi 변수 설정후 곱하기(*) 해서 출력해 보세요
radius = 5
pi = 3.14

area = radius * radius * pi
print(area)
# Out:
# 78.5

# %% [markdown]
# #### 3-2. 숫자형 연산
#     - 더하기, 빼기, 곱하기, 나누기
#     - 몫,나머지
#     - 제곱

# %%
사탕 = 13   # 현재 갖고 있는 사탕  - 연습을 위해서 변수명을 이제부터 한글로
사람 = 4 
과자 = 5

# %%
먹을것개수 = 사탕 + 과자
먹을것개수
# Out:
# 18

# %%
사탕 - 과자
# Out:
# 8

# %%
사탕 / 사람
# Out:
# 3.25

# %%
# 몫, 나머지
사탕 // 사람    # 13개의 사탕을 4명이 가지면, 3개씩(몫) 가지고 1개(나머지)가 남는다.
# Out:
# 3

# %%
사탕 % 사람
# Out:
# 1

# %%
a = 2
b = 3
a ** b # a 를 b 번 곱하기
# Out:
# 8

# %%
a = 5
b = 3

# 복합 연산자

# %%
# 현재 사탕 개수 : a
# 추가된 사탕 개수 : b
a = a + b
print(a)
# Out:
# 8

# %%
money = 50000
money = money + 20000
money = money - 8500
money = money - 5000
print(money)

money = money // 3000
print(money)
# Out:
# 56500
# 18

# %%
18 * 3000
# Out:
# 54000

# %%
money = 80_000
money += 25_000
money -= 9000
money -= 14500
money -= 5000
money += 3000
can_qty = money // 4500
result_monty = money % 4500
print("돈" + str(money))
print("살수 있는 음료 개수" + str(can_qty))
print("음료를 사고 남은 돈" + str(result_monty))
# Out:
# 돈79500
# 살수 있는 음료 개수17
# 음료를 사고 남은 돈3000
