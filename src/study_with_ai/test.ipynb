# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
print("오늘 점심 메뉴 추천 받습니다.")
# Out:
# 오늘 점심 메뉴 추천 받습니다.

# %% [markdown]
# # 이거는 큰제목
# ## 이거는 작은 제목
# ### 더 작은 제목
# #### 더더 작은 제목
# - 목록1
# - 목록2
#
# 1. 이거는 넘버링
# 2. 넘버링 2

# %%
print("셀2")
# Out:
# 셀2

# %%
print("테스트")
# Out:
# 테스트
